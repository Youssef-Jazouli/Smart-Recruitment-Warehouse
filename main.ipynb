# %%
import pandas as pd

# %%
def explore_data(file_name):
    df = pd.read_csv(
        file_name,
        sep=None,
        engine="python"
    )

    print("Columns:")
    print(df.columns)

# %%
explore_data(r"bronze_data\bundesliga.csv")
# Out:
# Columns:
# Index(['﻿"number"', 'player', 'team', 'apps', 'min', 'goals', 'NPG', 'a'], dtype='str')

# %%
explore_data(r"bronze_data\la_liga.csv")
# Out:
# Columns:
# Index(['﻿"number"', 'player', 'team', 'apps', 'min', 'goals', 'NPG', 'a'], dtype='str')

# %%
explore_data(r"bronze_data\Ligue_1.csv")
# Out:
# Columns:
# Index(['﻿"number"', 'player', 'team', 'apps', 'min', 'goals', 'NPG', 'a'], dtype='str')

# %%
explore_data(r"bronze_data\premier_league.csv")
# Out:
# Columns:
# Index(['﻿"number"', 'player', 'team', 'apps', 'min', 'goals', 'NPG', 'a'], dtype='str')

# %%
explore_data(r"bronze_data\serie_a.csv")
# Out:
# Columns:
# Index(['﻿"number"', 'player', 'team', 'apps', 'min', 'goals', 'NPG', 'a'], dtype='str')

# %%
explore_data(r"bronze_data\sofifa_pro_players_bronze_20260723_143815.csv")
# Out:
# Columns:
# Index(['﻿Unnamed: 0', 'Name', 'Age', 'Overall rating', 'Potential',
#        'Team & Contract', 'ID', 'Height', 'Weight', 'foot', 'Value', 'Wage',
#        'Acceleration', 'Sprint speed', 'Stamina', 'Strength', 'Interceptions',
#        'Vision', 'Composure', 'Standing tackle', 'Sliding tackle', 'GK Diving',
#        'GK Handling', 'GK Positioning', 'Weak foot', 'Skill moves',
#        'Attacking work rate', 'Defensive work rate', 'Unnamed: 28'],
#       dtype='str')

# %%
df = pd.read_csv(r"bronze_data\sofifa_pro_players_bronze_20260723_143815.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2793 entries, 0 to 2792
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           0 non-null      float64
#  1   Name                 2793 non-null   str
#  2   Age                  2793 non-null   int64
#  3   Overall rating       2793 non-null   int64
#  4   Potential            2793 non-null   int64
#  5   Team & Contract      2793 non-null   str
#  6   ID                   2793 non-null   int64
#  7   Height               2793 non-null   str
#  8   Weight               2793 non-null   str
#  9   foot                 2793 non-null   str
#  10  Value                2793 non-null   str
#  11  Wage                 2793 non-null   str
#  12  Acceleration         2793 non-null   int64
#  13  Sprint speed         2793 non-null   int64
#  14  Stamina              2793 non-null   int64
#  15  Strength             2793 non-null   int64
# ...
