# %%
import pandas as pd
import glob

for f in glob.glob("bronze_data/*.csv"):
    df = pd.read_csv(f, nrows=2)
    print(f"\n📁 Fichier: {f}")
    print(f"📋 Columns ({len(df.columns)}):", list(df.columns))
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/user/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
import os
import glob

# %%
df = pd.read_csv("sofifa_pro_players_bronze_20260723_143815.csv")

# %%
result = len(df.columns)

# %%
print(result-4)
# Out:
# 25

# %%
df2 = pd.read_csv("sofifa_advanced_metrics_20260724_115149.csv")

res = len(df2.columns)
print(res-4)
# Out:
# 20

# %%
BASE_DIR = os.path.dirname(os.getcwd())
BRONZE_DIR = os.path.join(BASE_DIR, "bronze_data")


sofifa_files = glob.glob(os.path.join(BRONZE_DIR, "sofifa_pro_players_bronze_*.csv"))

print(len(sofifa_files))

file_name = sofifa_files[0]
print(file_name)

# df_sofifa = pd.read_csv(sofifa_files[0])
# print(df_sofifa)
# Out:
# 1
# /home/you-jazou/Documents/Smart-Recruitment-Warehouse/bronze_data/sofifa_pro_players_bronze_20260723_143815.csv
